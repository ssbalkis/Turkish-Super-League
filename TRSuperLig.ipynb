# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("TurkishSuperLig.csv")
pd.set_option('display.max_columns', None)
data
# Out:
#     Div        Date   Time     HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    T1  11/08/2023  19:00  Trabzonspor   Antalyaspor     1     0   H     1
# 1    T1  12/08/2023  17:15    Kasimpasa    Ankaragucu     3     2   H     1
# 2    T1  12/08/2023  17:15    Konyaspor  Istanbulspor     1     1   D     0
# 3    T1  12/08/2023  19:45  Kayserispor   Galatasaray     0     0   D     0
# 4    T1  12/08/2023  19:45   Pendikspor     Hatayspor     1     5   A     0
# ..   ..         ...    ...          ...           ...   ...   ...  ..   ...
# 333  T1  27/04/2024  17:00    Hatayspor    Buyuksehyr     1     2   A     0
# 334  T1  28/04/2024  14:00   Alanyaspor  Istanbulspor     6     0   H     3
# 335  T1  28/04/2024  14:00   Pendikspor   Kayserispor     1     2   A     1
# 336  T1  28/04/2024  17:00     Rizespor    Ankaragucu     2     2   D     2
# 337  T1  28/04/2024  17:00  Trabzonspor     Gaziantep     4     2   H     0
#
# ...

# %%
df = pd.DataFrame(data)

# %%
column_headers = list(df.columns.values)
column_headers
# Out:
# ['Div',
#  'Date',
#  'Time',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'MaxH',
#  'MaxD',
#  'MaxA',
#  'AvgH',
#  'AvgD',
#  'AvgA',
#  'B365>2.5',
#  'B365<2.5',
#  'P>2.5',
#  'P<2.5',
#  'Max>2.5',
#  'Max<2.5',
#  'Avg>2.5',
#  'Avg<2.5',
#  'AHh',
#  'B365AHH',
#  'B365AHA',
#  'PAHH',
#  'PAHA',
#  'MaxAHH',
#  'MaxAHA',
#  'AvgAHH',
#  'AvgAHA',
#  'B365CH',
#  'B365CD',
#  'B365CA',
#  'BWCH',
#  'BWCD',
#  'BWCA',
#  'IWCH',
#  'IWCD',
#  'IWCA',
#  'PSCH',
#  'PSCD',
#  'PSCA',
#  'WHCH',
#  'WHCD',
#  'WHCA',
#  'VCCH',
#  'VCCD',
#  'VCCA',
#  'MaxCH',
#  'MaxCD',
#  'MaxCA',
#  'AvgCH',
#  'AvgCD',
#  'AvgCA',
# ...

# %%
df = df.drop(['Div'], axis=1)
df
# Out:
#            Date   Time     HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    11/08/2023  19:00  Trabzonspor   Antalyaspor     1     0   H     1     0
# 1    12/08/2023  17:15    Kasimpasa    Ankaragucu     3     2   H     1     0
# 2    12/08/2023  17:15    Konyaspor  Istanbulspor     1     1   D     0     1
# 3    12/08/2023  19:45  Kayserispor   Galatasaray     0     0   D     0     0
# 4    12/08/2023  19:45   Pendikspor     Hatayspor     1     5   A     0     2
# ..          ...    ...          ...           ...   ...   ...  ..   ...   ...
# 333  27/04/2024  17:00    Hatayspor    Buyuksehyr     1     2   A     0     1
# 334  28/04/2024  14:00   Alanyaspor  Istanbulspor     6     0   H     3     0
# 335  28/04/2024  14:00   Pendikspor   Kayserispor     1     2   A     1     1
# 336  28/04/2024  17:00     Rizespor    Ankaragucu     2     2   D     2     0
# 337  28/04/2024  17:00  Trabzonspor     Gaziantep     4     2   H     0     2
#
# ...

# %%
df.drop(df.iloc[:, 22:104], inplace=True, axis=1)
df
# Out:
#            Date   Time     HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    11/08/2023  19:00  Trabzonspor   Antalyaspor     1     0   H     1     0
# 1    12/08/2023  17:15    Kasimpasa    Ankaragucu     3     2   H     1     0
# 2    12/08/2023  17:15    Konyaspor  Istanbulspor     1     1   D     0     1
# 3    12/08/2023  19:45  Kayserispor   Galatasaray     0     0   D     0     0
# 4    12/08/2023  19:45   Pendikspor     Hatayspor     1     5   A     0     2
# ..          ...    ...          ...           ...   ...   ...  ..   ...   ...
# 333  27/04/2024  17:00    Hatayspor    Buyuksehyr     1     2   A     0     1
# 334  28/04/2024  14:00   Alanyaspor  Istanbulspor     6     0   H     3     0
# 335  28/04/2024  14:00   Pendikspor   Kayserispor     1     2   A     1     1
# 336  28/04/2024  17:00     Rizespor    Ankaragucu     2     2   D     2     0
# 337  28/04/2024  17:00  Trabzonspor     Gaziantep     4     2   H     0     2
#
# ...

# %%
column_headers = list(df.columns.values)
column_headers
# Out:
# ['Date',
#  'Time',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR']

# %%
team_list = list(df.HomeTeam.unique())
team_list
# Out:
# ['Trabzonspor',
#  'Kasimpasa',
#  'Konyaspor',
#  'Kayserispor',
#  'Pendikspor',
#  'Sivasspor',
#  'Ad. Demirspor',
#  'Fenerbahce',
#  'Alanyaspor',
#  'Karagumruk',
#  'Antalyaspor',
#  'Istanbulspor',
#  'Rizespor',
#  'Galatasaray',
#  'Hatayspor',
#  'Buyuksehyr',
#  'Besiktas',
#  'Gaziantep',
#  'Ankaragucu',
#  'Samsunspor']

# %%
len(team_list)
# Out:
# 20

# %%
df = df.replace(to_replace=['Trabzonspor',
 'Kasimpasa',
 'Konyaspor',
 'Kayserispor',
 'Pendikspor',
 'Sivasspor',
 'Ad. Demirspor',
 'Fenerbahce',
 'Alanyaspor',
 'Karagumruk',
 'Antalyaspor',
 'Istanbulspor',
 'Rizespor',
 'Galatasaray',
 'Hatayspor',
 'Buyuksehyr',
 'Besiktas',
 'Gaziantep',
 'Ankaragucu',
 'Samsunspor']
                       ,value=['Trabzonspor',
 'Kasımpaşa',
 'Konyaspor',
 'Kayserispor',
 'Pendikspor',
 'Sivasspor',
 'Adana Demirspor',
 'Fenerbahçe',
 'Alanyaspor',
 'Karagümrük',
 'Antalyaspor',
 'İstanbulspor',
 'Rizespor',
 'Galatasaray',
 'Hatayspor',
 'Başakşehir',
 'Beşiktaş',
 'Gaziantep',
 'Ankaragücü',
 'Samsunspor'])

# %%
df
# Out:
#            Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    11/08/2023  19:00  Trabzonspor    Antalyaspor     1     0   H     1
# 1    12/08/2023  17:15    Kasımpaşa     Ankaragücü     3     2   H     1
# 2    12/08/2023  17:15    Konyaspor   İstanbulspor     1     1   D     0
# 3    12/08/2023  19:45  Kayserispor    Galatasaray     0     0   D     0
# 4    12/08/2023  19:45   Pendikspor      Hatayspor     1     5   A     0
# ..          ...    ...          ...            ...   ...   ...  ..   ...
# 333  27/04/2024  17:00    Hatayspor     Başakşehir     1     2   A     0
# 334  28/04/2024  14:00   Alanyaspor   İstanbulspor     6     0   H     3
# 335  28/04/2024  14:00   Pendikspor    Kayserispor     1     2   A     1
# 336  28/04/2024  17:00     Rizespor     Ankaragücü     2     2   D     2
# 337  28/04/2024  17:00  Trabzonspor  Gaziantepspor     4     2   H     0
#
#      HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# ...

# %%
fb_home = df[df['HomeTeam'] == 'Fenerbahçe']
fb_home
# Out:
#            Date   Time    HomeTeam         AwayTeam  FTHG  FTAG FTR  HTHG  \
# 7    13/08/2023  19:45  Fenerbahçe    Gaziantepspor     2     1   H     2
# 40   17/09/2023  15:00  Fenerbahçe      Antalyaspor     3     2   H     1
# 58   28/09/2023  18:00  Fenerbahçe       Başakşehir     4     0   H     3
# 65   01/10/2023  14:00  Fenerbahçe         Rizespor     5     0   H     1
